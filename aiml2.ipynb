# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import datetime
# %matplotlib inline

# %%
Data = pd.read_excel("C:/Users/HP/Downloads/AIMLCWdataset.xlsx")
Data.reset_index(drop=True, inplace=True)
Data=pd.DataFrame(Data)
datetime_series = pd.to_datetime(Data['Date'])
datetime_index = pd.DatetimeIndex(datetime_series.values)
Data=Data.set_index(datetime_index)
Data.drop('Date',axis=1,inplace=True)
Data.head()
# Out:
#             PFGDAAU LX Equity  PFTEAAU LX Equity  MBIPEANV CI Equity  \
# 2017-03-02             105.04             105.07             10.5789
# 2017-10-02             105.04             105.07             10.6300
# 2017-02-17             105.04             105.07             10.5812
# 2017-02-24             105.04             105.07             10.5106
# 2017-03-03             106.02             105.91             10.3054
#
#             PFCSAAU LX Equity  BCPACCI PE Equity  PFARAAU LX Equity  \
# 2017-03-02             102.68           123.3494             116.07
# 2017-10-02             102.68           125.4631             116.07
# 2017-02-17             102.68           123.1535             116.07
# 2017-02-24             102.68           121.1794             116.07
# 2017-03-03             103.68           120.4186             117.05
#
#             PFBKAAU LX Equity  PFGOAAU LX Equity  MONLAEA CI Equity  \
# 2017-03-02              87.19             102.33          1153.2947
# ...

# %%
# Log of percentage change of all stocks in the list
Ret= Data.pct_change().apply(lambda x: np.log(1+x)) # CONVERT TO RETURN
Ret.head()
# Out:
#             PFGDAAU LX Equity  PFTEAAU LX Equity  MBIPEANV CI Equity  \
# 2017-03-02                NaN                NaN                 NaN
# 2017-10-02           0.000000           0.000000            0.004819
# 2017-02-17           0.000000           0.000000           -0.004601
# 2017-02-24           0.000000           0.000000           -0.006695
# 2017-03-03           0.009287           0.007963           -0.019716
#
#             PFCSAAU LX Equity  BCPACCI PE Equity  PFARAAU LX Equity  \
# 2017-03-02                NaN                NaN                NaN
# 2017-10-02           0.000000           0.016991           0.000000
# 2017-02-17           0.000000          -0.018580           0.000000
# 2017-02-24           0.000000          -0.016159           0.000000
# 2017-03-03           0.009692          -0.006298           0.008408
#
#             PFBKAAU LX Equity  PFGOAAU LX Equity  MONLAEA CI Equity  \
# 2017-03-02                NaN                NaN                NaN
# ...

# %%
Ann_Ret = Ret.mean()*52
print (Ann_Ret)
# Out:
# PFGDAAU LX Equity     0.109704
# PFTEAAU LX Equity     0.102305
# MBIPEANV CI Equity    0.046765
# PFCSAAU LX Equity     0.096473
# BCPACCI PE Equity     0.024888
#                         ...
# JGAMAUA ID Equity     0.067135
# BAUSDBA IJ Equity     0.019691
# WARINBU GU Equity     0.090941
# ALLMNBU BH Equity     0.061928
# MSUBPE1 ID Equity     0.027814
# Length: 166, dtype: float64

# %%
Ann_Risk=Ret.std()*(52)**(0.5)
print(Ann_Risk)
# Out:
# PFGDAAU LX Equity     0.064625
# PFTEAAU LX Equity     0.048721
# MBIPEANV CI Equity    0.190412
# PFCSAAU LX Equity     0.049611
# BCPACCI PE Equity     0.230986
#                         ...
# JGAMAUA ID Equity     0.111581
# BAUSDBA IJ Equity     0.078572
# WARINBU GU Equity     0.152016
# ALLMNBU BH Equity     0.114886
# MSUBPE1 ID Equity     0.047900
# Length: 166, dtype: float64

# %%
Data.columns
# Out:
# Index(['PFGDAAU LX Equity', 'PFTEAAU LX Equity', 'MBIPEANV CI Equity',
#        'PFCSAAU LX Equity', 'BCPACCI PE Equity', 'PFARAAU LX Equity',
#        'PFBKAAU LX Equity', 'PFGOAAU LX Equity', 'MONLAEA CI Equity',
#        'WEDINBU KY Equity',
#        ...
#        'AQRIX US Equity', 'SCEMAIA LX Equity', 'CABNX US Equity',
#        'TYGLCON SP Equity', 'FPACX US Equity', 'JGAMAUA ID Equity',
#        'BAUSDBA IJ Equity', 'WARINBU GU Equity', 'ALLMNBU BH Equity',
#        'MSUBPE1 ID Equity'],
#       dtype='object', length=166)

# %%
Ret_risk=(Ann_Ret/Ann_Risk)
print(Ret_risk)
# Out:
# PFGDAAU LX Equity     1.697542
# PFTEAAU LX Equity     2.099798
# MBIPEANV CI Equity    0.245599
# PFCSAAU LX Equity     1.944608
# BCPACCI PE Equity     0.107746
#                         ...
# JGAMAUA ID Equity     0.601669
# BAUSDBA IJ Equity     0.250611
# WARINBU GU Equity     0.598232
# ALLMNBU BH Equity     0.539044
# MSUBPE1 ID Equity     0.580659
# Length: 166, dtype: float64

# %%
ret_risk_data = Ret_risk.sort_values(ascending=False)
ret_risk_data
# Out:
# CCASORI MK Equity    5.477418
# CCASLTF MK Equity    5.140178
# BBFTOP3 KY Equity    4.133811
# BCUSDLF KK Equity    3.996748
# GMFDEBI LE Equity    2.566941
#                        ...
# MBAIX US Equity     -0.077355
# GPSLTAM AR Equity   -0.123547
# PDMAX US Equity     -0.330694
# BSSAA2U LX Equity   -0.536427
# SGTAAIA LX Equity   -0.681195
# Length: 166, dtype: float64

# %%
top20 = ret_risk_data.head(20)
top20
# Out:
# CCASORI MK Equity    5.477418
# CCASLTF MK Equity    5.140178
# BBFTOP3 KY Equity    4.133811
# BCUSDLF KK Equity    3.996748
# GMFDEBI LE Equity    2.566941
# LODFUIA LX Equity    2.311685
# PFTEAAU LX Equity    2.099798
# PFCSAAU LX Equity    1.944608
# PFARAAU LX Equity    1.843655
# PFGDAAU LX Equity    1.697542
# UBSFLBI LX Equity    1.681919
# PFGLAAU LX Equity    1.592386
# PFBKAAU LX Equity    1.481062
# PFGOAAU LX Equity    1.298728
# ALPCRDA LX Equity    1.181457
# AIBALMA AB Equity    1.167966
# ALCONGP AB Equity    1.102448
# BLUESPH BM Equity    1.034941
# INVGMII GU Equity    0.892583
# SCHGTRA LX Equity    0.876914
# dtype: float64

# %%
top20_ret = Ret[top20.index]
top20_ret
# Out:
#             CCASORI MK Equity  CCASLTF MK Equity  BBFTOP3 KY Equity  \
# 2017-03-02                NaN                NaN                NaN
# 2017-10-02           0.004212           0.004618           0.001523
# 2017-02-17           0.003012           0.004367           0.001150
# 2017-02-24           0.001133           0.001833           0.001557
# 2017-03-03          -0.000345          -0.001184           0.001526
# ...                       ...                ...                ...
# 2022-01-14           0.003360           0.002276           0.000953
# 2022-01-21           0.003281           0.003088           0.002346
# 2022-01-28          -0.001115          -0.000527           0.000500
# 2022-04-02          -0.000643          -0.000791           0.000063
# 2022-11-02           0.005028           0.003634           0.000042
#
#             BCUSDLF KK Equity  GMFDEBI LE Equity  LODFUIA LX Equity  \
# 2017-03-02                NaN                NaN                NaN
# ...

# %%
assets = pd.concat([Ann_Ret[top20.index],Ann_Risk[top20.index],Ret_risk[top20.index]], axis=1)
assets.columns = ['Ann Returns', 'Ann Risk', 'Return Risk Ratio']
assets
# Out:
#                    Ann Returns  Ann Risk  Return Risk Ratio
# CCASORI MK Equity     0.077142  0.014084           5.477418
# CCASLTF MK Equity     0.076088  0.014803           5.140178
# BBFTOP3 KY Equity     0.065189  0.015770           4.133811
# BCUSDLF KK Equity     0.013563  0.003394           3.996748
# GMFDEBI LE Equity     0.018239  0.007105           2.566941
# LODFUIA LX Equity     0.022722  0.009829           2.311685
# PFTEAAU LX Equity     0.102305  0.048721           2.099798
# PFCSAAU LX Equity     0.096473  0.049611           1.944608
# PFARAAU LX Equity     0.096325  0.052247           1.843655
# PFGDAAU LX Equity     0.109704  0.064625           1.697542
# UBSFLBI LX Equity     0.023838  0.014173           1.681919
# PFGLAAU LX Equity     0.060871  0.038226           1.592386
# PFBKAAU LX Equity     0.081057  0.054729           1.481062
# PFGOAAU LX Equity     0.074028  0.057000           1.298728
# ALPCRDA LX Equity     0.044967  0.038061           1.181457
# ...

# %%
Ret_Corr = top20_ret.corr()
Ret_Corr
# Out:
#                    CCASORI MK Equity  CCASLTF MK Equity  BBFTOP3 KY Equity  \
# CCASORI MK Equity           1.000000           0.604199          -0.019601
# CCASLTF MK Equity           0.604199           1.000000          -0.008581
# BBFTOP3 KY Equity          -0.019601          -0.008581           1.000000
# BCUSDLF KK Equity          -0.021079           0.040492          -0.047489
# GMFDEBI LE Equity          -0.232153          -0.127595           0.084205
# LODFUIA LX Equity          -0.245674          -0.162448           0.070913
# PFTEAAU LX Equity          -0.214661          -0.122256          -0.059324
# PFCSAAU LX Equity          -0.196981          -0.104837          -0.080871
# PFARAAU LX Equity          -0.175510          -0.085626          -0.041910
# PFGDAAU LX Equity          -0.214396          -0.101241          -0.064879
# UBSFLBI LX Equity           0.147776           0.127475           0.061339
# ...

# %%
plt.subplots(figsize=(11, 8))
sb.heatmap(Ret_Corr, linewidths=.5, )
# Out:
# <AxesSubplot:>

# %%
top12 = {'GMFDEBI LE Equity', 'LODFUIA LX Equity', 'PFTEAAU LX Equity',
         'PFCSAAU LX Equity','PFARAAU LX Equity', 'PFGDAAU LX Equity',
         'UBSFLBI LX Equity','ALCONGP AB Equity', 'PFGLAAU LX Equity'
         ,'PFBKAAU LX Equity','AIBALMA AB Equity','BLUESPH BM Equity'}

# %%
Ret_Covar = top20_ret[top12].cov()
Ret_Covar
# Out:
#                    AIBALMA AB Equity  GMFDEBI LE Equity  BLUESPH BM Equity  \
# AIBALMA AB Equity       7.202581e-05      -3.870392e-07      -3.275306e-06
# GMFDEBI LE Equity      -3.870392e-07       9.708521e-07       1.977578e-06
# BLUESPH BM Equity      -3.275306e-06       1.977578e-06       2.352736e-05
# PFGDAAU LX Equity      -7.356645e-06       3.167436e-06       2.463475e-05
# LODFUIA LX Equity      -1.308475e-06       9.573377e-07       2.963312e-06
# PFBKAAU LX Equity      -4.229364e-06       3.020380e-06       2.079543e-05
# ALCONGP AB Equity       2.761479e-05       6.906775e-08       1.029905e-06
# PFCSAAU LX Equity      -5.365365e-06       2.987944e-06       1.774002e-05
# PFARAAU LX Equity      -3.953648e-06       3.526000e-06       1.930319e-05
# PFGLAAU LX Equity       6.806027e-06       1.044518e-06       1.010713e-05
# UBSFLBI LX Equity       6.939346e-06       5.889408e-08       3.950129e-07
# ...

# %%
# w = [0.08333]*12
w={'GMFDEBI LE Equity' : 0.08333, 'LODFUIA LX Equity' : 0.08333, 'PFTEAAU LX Equity' : 0.08333,
   'PFCSAAU LX Equity' : 0.08333,'PFARAAU LX Equity' : 0.08333, 'PFGDAAU LX Equity' : 0.08333,
   'UBSFLBI LX Equity' : 0.08333,'ALCONGP AB Equity' : 0.08333, 'PFGLAAU LX Equity' : 0.08333
  ,'PFBKAAU LX Equity' : 0.08333,'AIBALMA AB Equity' : 0.08333,'BLUESPH BM Equity' : 0.08333
  }
port_var = Ret_Covar.mul(w, axis=0).mul(w, axis=1).sum().sum()
Ann_port_std = (port_var*52)**(0.5)
print (port_var)
print (port_var*52)
# Out:
# 1.3263127230379367e-05
# 0.0006896826159797271

# %%
Ann_port_std
# Out:
# 0.026261809076674955

# %%
# Yearly returns for individual companies
data = Data[top20.index]
ind_er = data[top12].resample('Y').last().pct_change().mean()
ind_er = pd.DataFrame(ind_er)
ind_er
# Out:
#                           0
# AIBALMA AB Equity  0.067101
# GMFDEBI LE Equity  0.015102
# BLUESPH BM Equity  0.024840
# PFGDAAU LX Equity  0.103077
# LODFUIA LX Equity  0.018503
# PFBKAAU LX Equity  0.065727
# ALCONGP AB Equity  0.035823
# PFCSAAU LX Equity  0.086248
# PFARAAU LX Equity  0.080943
# PFGLAAU LX Equity  0.047416
# UBSFLBI LX Equity  0.021132
# PFTEAAU LX Equity  0.088457

# %%
# Portfolio returns
ann_ret = Ann_Ret[top20.index]
w = 0.08333*0.08333*0.08333*0.08333*0.08333*0.08333*0.08333*0.08333*0.08333*0.08333*0.08333*0.08333
port_er = (w*Ann_Ret).sum()
port_er
# Out:
# 6.782566445000398e-13

# %%
# Volatility is given by the annual standard deviation. We multiply by 252 because there are 252 trading days/year.
ann_sd = data[top12].pct_change().apply(lambda x: np.log(1+x)).std().apply(lambda x: x*np.sqrt(252))
ann_sd
# Out:
# AIBALMA AB Equity    0.134724
# GMFDEBI LE Equity    0.015641
# BLUESPH BM Equity    0.076999
# PFGDAAU LX Equity    0.142265
# LODFUIA LX Equity    0.021638
# PFBKAAU LX Equity    0.120481
# ALCONGP AB Equity    0.089849
# PFCSAAU LX Equity    0.109213
# PFARAAU LX Equity    0.115016
# PFGLAAU LX Equity    0.084151
# UBSFLBI LX Equity    0.031200
# PFTEAAU LX Equity    0.107255
# dtype: float64

# %%
assets = pd.concat([ind_er, ann_sd], axis=1) # Creating a table for visualising returns and volatility of assets
assets.columns = ['Returns', 'Volatility']
assets
# Out:
#                     Returns  Volatility
# AIBALMA AB Equity  0.067101    0.134724
# GMFDEBI LE Equity  0.015102    0.015641
# BLUESPH BM Equity  0.024840    0.076999
# PFGDAAU LX Equity  0.103077    0.142265
# LODFUIA LX Equity  0.018503    0.021638
# PFBKAAU LX Equity  0.065727    0.120481
# ALCONGP AB Equity  0.035823    0.089849
# PFCSAAU LX Equity  0.086248    0.109213
# PFARAAU LX Equity  0.080943    0.115016
# PFGLAAU LX Equity  0.047416    0.084151
# UBSFLBI LX Equity  0.021132    0.031200
# PFTEAAU LX Equity  0.088457    0.107255

# %%
import matplotlib.pyplot as plt
x = ann_sd # RISK
y = ind_er # Return
plt.scatter(x, y)
plt.show()

# %%
p_ret = [] # Define an empty array for portfolio returns
p_vol = [] # Define an empty array for portfolio volatility
p_weights = [] # Define an empty array for asset weights

num_assets = len(data[top12].columns)
num_portfolios = 5000

# %%
for portfolio in range(num_portfolios):
    weights = np.random.random(num_assets)
    weights = weights/np.sum(weights)
    p_weights.append(weights)
    returns = np.dot(weights, ind_er) # Returns are the product of individual expected returns of asset and its
 # weights
    p_ret.append(returns)
    var = Ret_Covar.mul(weights, axis=0).mul(weights, axis=1).sum().sum() # Portfolio Variance
    sd = np.sqrt(var) #Daily standard deviation
    ann_sd = sd*np.sqrt(252) #Annual standard deviation = volatility
    p_vol.append(ann_sd)

# %%
calc_data = {'Returns':p_ret, 'Volatility':p_vol}
for counter, symbol in enumerate(data[top12].columns.tolist()):
 #print(counter, symbol)
 calc_data[symbol+' weight'] = [w[counter] for w in p_weights]
portfolios = pd.DataFrame(calc_data)
portfolios.head() # Dataframe of the 10000 portfolios created
# Out:
#                   Returns  Volatility  AIBALMA AB Equity weight  \
# 0  [0.054490824981520816]    0.056408                  0.079827
# 1   [0.06253847349849566]    0.070640                  0.102268
# 2  [0.055520500114275284]    0.058764                  0.082850
# 3  [0.056961853390384565]    0.059432                  0.149746
# 4   [0.05638155561825842]    0.056828                  0.153590
#
#    GMFDEBI LE Equity weight  BLUESPH BM Equity weight  \
# 0                  0.082219                  0.076453
# 1                  0.102978                  0.021675
# 2                  0.026645                  0.015140
# 3                  0.019412                  0.039043
# 4                  0.087095                  0.090096
#
#    PFGDAAU LX Equity weight  LODFUIA LX Equity weight  \
# 0                  0.120374                  0.096462
# 1                  0.032813                  0.072415
# 2                  0.084520                  0.059414
# ...

# %%
# Plot efficient frontier
portfolios.plot.scatter(x='Volatility', y='Returns', marker='o', s=10, alpha=0.3, grid=True, figsize=[5,5])
# Out:
# <AxesSubplot:xlabel='Volatility', ylabel='Returns'>

# %%
min_vol_port = portfolios.iloc[portfolios['Volatility'].idxmin()]
# idxmin() gives us the minimum value in the column specified.
min_vol_port
# Out:
# Returns                     [0.03687586729834591]
# Volatility                               0.035978
# AIBALMA AB Equity weight                 0.102259
# GMFDEBI LE Equity weight                 0.099903
# BLUESPH BM Equity weight                 0.041261
# PFGDAAU LX Equity weight                 0.024026
# LODFUIA LX Equity weight                 0.208933
# PFBKAAU LX Equity weight                 0.018359
# ALCONGP AB Equity weight                 0.040782
# PFCSAAU LX Equity weight                 0.026137
# PFARAAU LX Equity weight                 0.000375
# PFGLAAU LX Equity weight                 0.192773
# UBSFLBI LX Equity weight                 0.217507
# PFTEAAU LX Equity weight                 0.027685
# Name: 2456, dtype: object

# %%
# plotting the minimum volatility portfolio
plt.subplots(figsize=[6,5])
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=200)

# %%
# Finding the optimal portfolio
rf = 0.01 # risk factor
optimal_risky_port = portfolios.iloc[((portfolios['Returns']-rf)/portfolios['Volatility']).astype(float).idxmax()]
optimal_risky_port
# Out:
# Returns                     [0.06596138822871031]
# Volatility                               0.064307
# AIBALMA AB Equity weight                 0.175851
# GMFDEBI LE Equity weight                 0.023745
# BLUESPH BM Equity weight                 0.011247
# PFGDAAU LX Equity weight                  0.20009
# LODFUIA LX Equity weight                 0.067724
# PFBKAAU LX Equity weight                 0.022466
# ALCONGP AB Equity weight                 0.017446
# PFCSAAU LX Equity weight                 0.107082
# PFARAAU LX Equity weight                 0.009411
# PFGLAAU LX Equity weight                 0.048222
# UBSFLBI LX Equity weight                 0.159753
# PFTEAAU LX Equity weight                 0.156964
# Name: 2688, dtype: object
